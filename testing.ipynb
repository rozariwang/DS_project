# %%
import controller

controller.generate_recommendation("A - Agilent Technologies Inc. Common Stock")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import controller
#       3 controller.generate_recommendation("A - Agilent Technologies Inc. Common Stock")
#
# File g:\My Drive\UdS\Classes\Data Science\DS_project\controller.py:8
#       6 import torch
#       7 import yahoo_fin.stock_info as si
# ----> 8 from stocksent.sentiment import Sentiment
#       9 from transformers import AutoModelForSequenceClassification, AutoTokenizer
#      11 ''' :)
#      12 # Retrieve OpenAI API credentials from secrets.toml
#      13 secrets = st.secrets["openai"]
#      14 openai_organization = secrets["openai_organization"]
#      15 openai_api = secrets["openai_api"]
#      16 '''
#
# File c:\Users\William\AppData\Local\Programs\Python\Python38\lib\site-packages\stocksent\__init__.py:2
#       1 # This line of code will allow shorter imports
# ...
